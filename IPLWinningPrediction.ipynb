# %%
import pandas as pd
import numpy as np

# %%
matches=pd.read_csv("matches.csv")
deliveries=pd.read_csv("deliveries.csv")
print(matches.shape,deliveries.shape)
# Out:
# (756, 18) (179078, 21)

# %%
#reset index convert series into data frame
totalrun_df = deliveries.groupby(['match_id','inning']).sum()['total_runs'].reset_index()
totalrun_df
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 1            1       2         172
# 2            2       1         184
# 3            2       2         187
# 4            3       1         183
# ...        ...     ...         ...
# 1523     11413       2         170
# 1524     11414       1         155
# 1525     11414       2         162
# 1526     11415       1         152
# 1527     11415       2         157
#
# [1528 rows x 3 columns]

# %%
totalrun_df=totalrun_df[totalrun_df["inning"]==1]

#totalrun_df["total_runs"]=totalrun_df["total_runs"]+1
#or another method to do is using lambda 
totalrun_df['total_runs'] = totalrun_df['total_runs'].apply(lambda x:x+1)


totalrun_df
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6184\424562356.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   totalrun_df['total_runs'] = totalrun_df['total_runs'].apply(lambda x:x+1)
#       match_id  inning  total_runs
# 0            1       1         208
# 2            2       1         185
# 4            3       1         184
# 6            4       1         164
# 8            5       1         158
# ...        ...     ...         ...
# 1518     11347       1         144
# 1520     11412       1         137
# 1522     11413       1         172
# 1524     11414       1         156
# 1526     11415       1         153
#
# [756 rows x 3 columns]

# %%
match_df = matches.merge(totalrun_df[['match_id','total_runs']],left_on='id',right_on='match_id')
match_df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
match_df['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
teams = [
    'Sunrisers Hyderabad',
    'Mumbai Indians',
    'Royal Challengers Bangalore',
    'Kolkata Knight Riders',
    'Kings XI Punjab',
    'Chennai Super Kings',
    'Rajasthan Royals',
    'Delhi Capitals'
]

# %%
# replacing the Delhi Daredevils with Delhi Capitals

match_df['team1'] = match_df['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
match_df['team2'] = match_df['team2'].str.replace('Delhi Daredevils','Delhi Capitals')

# replacing the Deccan Chargers with Sunrises Hyderabad

match_df['team1'] = match_df['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['team2'] = match_df['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

# replacing the rising pune super giant with csk

match_df['team1'] = match_df['team1'].str.replace('Rising Pune Supergiants','Chennai Super Kings')
match_df['team2'] = match_df['team2'].str.replace('Rising Pune Supergiants','Chennai Super Kings')

# %%
match_df=match_df[match_df["team1"].isin(teams)]
match_df=match_df[match_df["team2"].isin(teams)]

match_df["team1"].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Kings XI Punjab', 'Delhi Capitals',
#        'Mumbai Indians', 'Chennai Super Kings', 'Rajasthan Royals'],
#       dtype=object)

# %%
match_df[match_df['dl_applied']==1].style.background_gradient(cmap = 'plasma')
# Out:
# <style type="text/css">
# #T_61ac0_row0_col0, #T_61ac0_row0_col9, #T_61ac0_row0_col11, #T_61ac0_row0_col18, #T_61ac0_row1_col9, #T_61ac0_row1_col12, #T_61ac0_row2_col9, #T_61ac0_row2_col12, #T_61ac0_row3_col9, #T_61ac0_row3_col11, #T_61ac0_row4_col9, #T_61ac0_row4_col12, #T_61ac0_row5_col9, #T_61ac0_row5_col12, #T_61ac0_row6_col9, #T_61ac0_row6_col12, #T_61ac0_row7_col9, #T_61ac0_row7_col11, #T_61ac0_row7_col19, #T_61ac0_row8_col9, #T_61ac0_row8_col11, #T_61ac0_row9_col9, #T_61ac0_row9_col12, #T_61ac0_row10_col9, #T_61ac0_row10_col11, #T_61ac0_row11_col9, #T_61ac0_row11_col12, #T_61ac0_row12_col9, #T_61ac0_row12_col11, #T_61ac0_row13_col9, #T_61ac0_row13_col12, #T_61ac0_row14_col9, #T_61ac0_row14_col12, #T_61ac0_row15_col9, #T_61ac0_row15_col12, #T_61ac0_row16_col9, #T_61ac0_row16_col11, #T_61ac0_row17_col9, #T_61ac0_row17_col12 {
#   background-color: #0d0887;
#   color: #f1f1f1;
# }
# #T_61ac0_row0_col12 {
#   background-color: #f2844b;
#   color: #f1f1f1;
# }
# ...

# %%
# ignoring the rows which were DL method

#match_df = match_df[match_df['dl_applied']==0]

# considering the match_id,city,winner and total runs
match_df = match_df[['match_id','city','winner','total_runs']]

# %%
match_df
# Out:
#      match_id           city                       winner  total_runs
# 0           1      Hyderabad          Sunrisers Hyderabad         208
# 4           5      Bangalore  Royal Challengers Bangalore         158
# 6           7         Mumbai               Mumbai Indians         179
# 7           8         Indore              Kings XI Punjab         149
# 9          10         Mumbai               Mumbai Indians         159
# ..        ...            ...                          ...         ...
# 751     11347         Mumbai               Mumbai Indians         144
# 752     11412        Chennai               Mumbai Indians         137
# 753     11413  Visakhapatnam               Delhi Capitals         172
# 754     11414  Visakhapatnam          Chennai Super Kings         156
# 755     11415      Hyderabad               Mumbai Indians         153
#
# [653 rows x 4 columns]

# %%
delivery_df = match_df.merge(deliveries,on='match_id')
delivery_df.head(5)
# Out:
#    match_id       city               winner  total_runs_x  inning  \
# 0         1  Hyderabad  Sunrisers Hyderabad           208       1
# 1         1  Hyderabad  Sunrisers Hyderabad           208       1
# 2         1  Hyderabad  Sunrisers Hyderabad           208       1
# 3         1  Hyderabad  Sunrisers Hyderabad           208       1
# 4         1  Hyderabad  Sunrisers Hyderabad           208       1
#
#           batting_team                 bowling_team  over  ball    batsman  \
# 0  Sunrisers Hyderabad  Royal Challengers Bangalore     1     1  DA Warner
# 1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     2  DA Warner
# 2  Sunrisers Hyderabad  Royal Challengers Bangalore     1     3  DA Warner
# 3  Sunrisers Hyderabad  Royal Challengers Bangalore     1     4  DA Warner
# 4  Sunrisers Hyderabad  Royal Challengers Bangalore     1     5  DA Warner
#
#    ... bye_runs legbye_runs  noball_runs  penalty_runs  batsman_runs  \
# ...

# %%
delivery_df=delivery_df[delivery_df["inning"]==2]
delivery_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           208       2
# 126         1  Hyderabad  Sunrisers Hyderabad           208       2
# 127         1  Hyderabad  Sunrisers Hyderabad           208       2
# 128         1  Hyderabad  Sunrisers Hyderabad           208       2
# 129         1  Hyderabad  Sunrisers Hyderabad           208       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... bye_runs legbye_runs  noball_runs  penalty_runs  \
# 125       CH Gayle  ...        0           0            0             0
# ...

# %%
delivery_df['current_score'] = delivery_df.groupby('match_id')['total_runs_y'].cumsum()

# Display the first few rows of the updated DataFrame
delivery_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           208       2
# 126         1  Hyderabad  Sunrisers Hyderabad           208       2
# 127         1  Hyderabad  Sunrisers Hyderabad           208       2
# 128         1  Hyderabad  Sunrisers Hyderabad           208       2
# 129         1  Hyderabad  Sunrisers Hyderabad           208       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... legbye_runs noball_runs  penalty_runs  batsman_runs  \
# 125       CH Gayle  ...           0           0             0             1
# ...

# %%
delivery_df['runs_left'] = delivery_df['total_runs_x']-delivery_df['current_score']

delivery_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           208       2
# 126         1  Hyderabad  Sunrisers Hyderabad           208       2
# 127         1  Hyderabad  Sunrisers Hyderabad           208       2
# 128         1  Hyderabad  Sunrisers Hyderabad           208       2
# 129         1  Hyderabad  Sunrisers Hyderabad           208       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... noball_runs penalty_runs  batsman_runs  extra_runs  \
# 125       CH Gayle  ...           0            0             1           0
# ...

# %%
delivery_df['balls_left'] = 126-(delivery_df['over']*6+delivery_df['ball'])

delivery_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           208       2
# 126            1  Hyderabad  Sunrisers Hyderabad           208       2
# 127            1  Hyderabad  Sunrisers Hyderabad           208       2
# 128            1  Hyderabad  Sunrisers Hyderabad           208       2
# 129            1  Hyderabad  Sunrisers Hyderabad           208       2
# ...          ...        ...                  ...           ...     ...
# 154764     11415  Hyderabad       Mumbai Indians           153       2
# 154765     11415  Hyderabad       Mumbai Indians           153       2
# 154766     11415  Hyderabad       Mumbai Indians           153       2
# 154767     11415  Hyderabad       Mumbai Indians           153       2
# 154768     11415  Hyderabad       Mumbai Indians           153       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].fillna("0")

delivery_df['player_dismissed'] = delivery_df['player_dismissed'].apply(lambda x:x if x=="0" else "1")


delivery_df['player_dismissed'] = delivery_df['player_dismissed'].astype('int')


delivery_df['player_dismissed'].unique()
# Out:
# array([0, 1])

# %%
# Calculate cumulative sum of wickets taken by players in each match
wickets = delivery_df.groupby('match_id')['player_dismissed'].cumsum()

# Subtract cumulative wickets from total 10 to get remaining wickets
delivery_df['wickets'] = 10 - wickets.values

# to display or save the entire DataFrame
delivery_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           208       2
# 126            1  Hyderabad  Sunrisers Hyderabad           208       2
# 127            1  Hyderabad  Sunrisers Hyderabad           208       2
# 128            1  Hyderabad  Sunrisers Hyderabad           208       2
# 129            1  Hyderabad  Sunrisers Hyderabad           208       2
# ...          ...        ...                  ...           ...     ...
# 154764     11415  Hyderabad       Mumbai Indians           153       2
# 154765     11415  Hyderabad       Mumbai Indians           153       2
# 154766     11415  Hyderabad       Mumbai Indians           153       2
# 154767     11415  Hyderabad       Mumbai Indians           153       2
# 154768     11415  Hyderabad       Mumbai Indians           153       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
# current run rate
delivery_df['cur_run_rate'] = (delivery_df['current_score']*6)/(120-delivery_df['balls_left'])

# required run rate
delivery_df['req_run_rate'] = (delivery_df['runs_left']*6)/(delivery_df['balls_left'])

# %%
def resultf(row):
    return 1 if row['batting_team']==row['winner'] else 0

# %%
delivery_df['result']=delivery_df.apply(resultf,axis=1)
delivery_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           208       2
# 126            1  Hyderabad  Sunrisers Hyderabad           208       2
# 127            1  Hyderabad  Sunrisers Hyderabad           208       2
# 128            1  Hyderabad  Sunrisers Hyderabad           208       2
# 129            1  Hyderabad  Sunrisers Hyderabad           208       2
# ...          ...        ...                  ...           ...     ...
# 154764     11415  Hyderabad       Mumbai Indians           153       2
# 154765     11415  Hyderabad       Mumbai Indians           153       2
# 154766     11415  Hyderabad       Mumbai Indians           153       2
# 154767     11415  Hyderabad       Mumbai Indians           153       2
# 154768     11415  Hyderabad       Mumbai Indians           153       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
final_df = delivery_df[['batting_team','bowling_team','city','runs_left',
                        'balls_left','wickets','total_runs_x','cur_run_rate',
                        'req_run_rate','result']]

final_df.head()
# Out:
#                     batting_team         bowling_team       city  runs_left  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        207
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        207
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        207
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        205
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        201
#
#      balls_left  wickets  total_runs_x  cur_run_rate  req_run_rate  result
# 125         119       10           208           6.0     10.436975       0
# 126         118       10           208           3.0     10.525424       0
# 127         117       10           208           2.0     10.615385       0
# 128         116       10           208           4.5     10.603448       0
# 129         115       10           208           8.4     10.486957       0

# %%
final_df = final_df.dropna()

final_df.isnull().sum()
# Out:
# batting_team    0
# bowling_team    0
# city            0
# runs_left       0
# balls_left      0
# wickets         0
# total_runs_x    0
# cur_run_rate    0
# req_run_rate    0
# result          0
# dtype: int64

# %%
final_df = final_df[final_df['balls_left'] != 0]

# %%
data = final_df.copy()

test = data['result']

train = data.drop(['result'],axis = 1)

train.head()
# Out:
#                     batting_team         bowling_team       city  runs_left  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        207
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        207
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        207
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        205
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        201
#
#      balls_left  wickets  total_runs_x  cur_run_rate  req_run_rate
# 125         119       10           208           6.0     10.436975
# 126         118       10           208           3.0     10.525424
# 127         117       10           208           2.0     10.615385
# 128         116       10           208           4.5     10.603448
# 129         115       10           208           8.4     10.486957

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(train,test,test_size=.2,random_state=1)

# %% [markdown]
# # MODEL_BUILDING

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn import metrics

# %%
cf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
],remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',cf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# fitting the training data

pipe.fit(X_train,y_train)
# Out:
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred = pipe.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.8005172531137277

# %%
pipe.predict_proba(X_test)[100]
# Out:
# array([0.18874308, 0.81125692])

# %%
#will avoiding using this 
pipe2 = Pipeline(steps=[
    ('step1',cf),
    ('step2',RandomForestClassifier())
])

pipe2.fit(X_train,y_train)
print(metrics.accuracy_score(y_test,pipe2.predict(X_test)))
# Out:
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# 0.9990471653168176

# %%
pipe2.predict_proba(X_test)[10]
# Out:
# array([0.98, 0.02])

# %%
def match_summary(row):
    print("Batting Team-" + row['batting_team'] + " | Bowling Team-" + row['bowling_team'] + " | Target- " + str(row['total_runs_x']))

# %%
def match_progression(x_df, match_id, pipe):
    # Filter data for the specified match_id and only full overs (ball == 6)
    match = x_df[(x_df['match_id'] == match_id) & (x_df['ball'] == 6)]
    
    # Drop rows with missing values in relevant columns
    match = match.dropna(subset=['batting_team', 'bowling_team', 'city', 'runs_left', 'balls_left', 
                                  'wickets', 'total_runs_x', 'cur_run_rate', 'req_run_rate'])
    
    # Exclude rows where balls_left is zero
    match = match[match['balls_left'] != 0]
    
    # Predict probabilities using the provided pipeline
    result = pipe.predict_proba(match)
    
    # Calculate win and lose probabilities and append to DataFrame
    match['lose'] = np.round(result[:, 0] * 100, 1)
    match['win'] = np.round(result[:, 1] * 100, 1)
    
    # Add end_of_over column
    match['end_of_over'] = np.arange(1, match.shape[0] + 1)
    
    # Calculate runs scored and wickets taken in the current over
    match['runs_after_over'] = match['total_runs_x'] - match['runs_left']
    match['wickets_in_over'] = 10 - match['wickets']
    
    # Print target runs
    target = match['total_runs_x'].iloc[0]
    print("Target -", target)
    
    # Select required columns and return DataFrame along with target runs
    return match[['end_of_over', 'runs_after_over', 'wickets_in_over', 'lose', 'win']], target

# %%
temp_df,target = match_progression(delivery_df,74,pipe)
temp_df
# Out:
# Target - 179
#        end_of_over  runs_after_over  wickets_in_over  lose   win
# 10616            1                4                0  57.5  42.5
# 10624            2               12                0  52.0  48.0
# 10630            3               13                0  58.6  41.4
# 10636            4               20                1  70.2  29.8
# 10642            5               32                1  60.2  39.8
# 10648            6               45                1  47.9  52.1
# 10654            7               54                1  41.9  58.1
# 10662            8               69                1  28.1  71.9
# 10668            9               76                1  25.8  74.2
# 10675           10               93                1  14.3  85.7
# 10681           11              102                2  19.9  80.1
# 10687           12              111                2  16.4  83.6
# 10693           13              119                2  14.1  85.9
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18,8))
plt.plot(temp_df['end_of_over'],temp_df['wickets_in_over'],color='yellow',linewidth=3)
plt.plot(temp_df['end_of_over'],temp_df['win'],color='#00a65a',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['lose'],color='red',linewidth=4)
plt.bar(temp_df['end_of_over'],temp_df['runs_after_over'])
plt.title('Target-' + str(target))
# Out:
# Text(0.5, 1.0, 'Target-179')

# %%
delivery_df['city'].unique()
# Out:
# array(['Hyderabad', 'Bangalore', 'Mumbai', 'Indore', 'Kolkata', 'Delhi',
#        'Chandigarh', 'Jaipur', 'Chennai', 'Cape Town', 'Port Elizabeth',
#        'Durban', 'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi', 'Abu Dhabi',
#        'Sharjah', nan, 'Mohali', 'Bengaluru'], dtype=object)

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))
